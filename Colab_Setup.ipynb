# %% [markdown]
# # Shinyy's Face Swapper - Google Colab
# Run this notebook to start the face swapper in Colab

# %%
# Clone repository
# !git clone https://github.com/YOUR_USERNAME/YOUR_REPO.git
# %cd YOUR_REPO

# %%
# Download models from public sources
print('Downloading shinyyswapper.onnx...')
# !wget -O shinyyswapper.onnx 'https://huggingface.co/deepinsight/inswapper/resolve/main/inswapper_128.onnx'

print('\nDownloading GFPGANv1.4.pth...')
# !mkdir -p models
# !wget -O models/GFPGANv1.4.pth 'https://github.com/TencentARC/GFPGAN/releases/download/v1.3.0/GFPGANv1.4.pth'

print('\nDownloading RealESRGAN_x2plus.pth...')
# !wget -O models/RealESRGAN_x2plus.pth 'https://github.com/xinntao/Real-ESRGAN/releases/download/v0.2.1/RealESRGAN_x2plus.pth'

print('\n✓ All models downloaded!')

# %%
# Install dependencies
# !pip install -q -r config/requirements.txt
print('✓ Dependencies installed!')

# %%
# Start Flask in background
import subprocess
import time

flask_process = subprocess.Popen(['python', 'app_flask.py'])
print('Starting Flask...')
time.sleep(5)
print('✓ Flask started!')

# %%
# Create public URL with ngrok
# !pip install -q pyngrok
from pyngrok import ngrok
from IPython.display import IFrame

public_url = ngrok.connect(80)
print(f'\n🚀 PUBLIC URL: {public_url}')
print(f'\nOpen this link to access your face swapper!')

# Display website inside Colab
print('\n📱 Website preview below:')
IFrame(src=public_url, width=1000, height=800)
